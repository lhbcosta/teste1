# %%
import pandas as pd

# %%
df = pd.read_csv('covid19.csv', sep = ',')

# %%
pd.read_csv('covid19.csv', sep = ',')
# Out:
#         epidemiological_week        date  order_for_place state          city  \
# 0                         22  2020-05-30               63    AC    Acrelândia
# 1                         22  2020-05-30               30    AC  Assis Brasil
# 2                         22  2020-05-30               22    AC     Brasiléia
# 3                         22  2020-05-30               53    AC        Bujari
# 4                         22  2020-05-30               23    AC      Capixaba
# ...                      ...         ...              ...   ...           ...
# 141180                     9  2020-02-27                3    SP           NaN
# 141181                     9  2020-02-26                2    SP     São Paulo
# 141182                     9  2020-02-26                2    SP           NaN
# 141183                     9  2020-02-25                1    SP     São Paulo
# 141184                     9  2020-02-25                1    SP           NaN
#
# ...

# %%
agrupadoestado = df[['last_available_confirmed']].groupby(df['state'])

# %%
agrupadoestado.sum()
# Out:
#        last_available_confirmed
# state
# AC                       159883
# AL                       255255
# AM                      1306985
# AP                       273700
# BA                       612599
# CE                      1641823
# DF                       315190
# ES                       477978
# GO                       126558
# MA                       933672
# MG                       349040
# MS                        47820
# MT                        68393
# PA                       996526
# PB                       311264
# PE                      1263180
# PI                       151591
# PR                       201004
# RJ                      1784171
# RN                       233990
# RO                       136972
# RR                       111394
# RS                       307376
# SC                       352065
# SE                       200140
# SP                      4425220
# TO                        95727

# %%
df.date.unique()
# Out:
# array(['2020-05-30', '2020-05-29', '2020-05-28', '2020-05-27',
#        '2020-05-26', '2020-05-25', '2020-05-24', '2020-05-23',
#        '2020-05-22', '2020-05-21', '2020-05-20', '2020-05-19',
#        '2020-05-18', '2020-05-17', '2020-05-16', '2020-05-15',
#        '2020-05-14', '2020-05-13', '2020-05-12', '2020-05-11',
#        '2020-05-10', '2020-05-09', '2020-05-08', '2020-05-07',
#        '2020-05-06', '2020-05-05', '2020-05-04', '2020-05-03',
#        '2020-05-02', '2020-05-01', '2020-04-30', '2020-04-29',
#        '2020-04-28', '2020-04-27', '2020-04-26', '2020-04-25',
#        '2020-04-24', '2020-04-23', '2020-04-22', '2020-04-21',
#        '2020-04-20', '2020-04-19', '2020-04-18', '2020-04-17',
#        '2020-04-16', '2020-04-15', '2020-04-14', '2020-04-13',
#        '2020-04-12', '2020-04-11', '2020-04-10', '2020-04-09',
#        '2020-04-08', '2020-04-07', '2020-04-06', '2020-04-05',
#        '2020-04-04', '2020-04-03', '2020-04-02', '2020-04-01',
# ...

# %%
agrupadodata = df[['new_confirmed']].groupby(df['date']).sum()

# %%
agrupadodata
# Out:
#             new_confirmed
# date
# 2020-02-25              2
# 2020-02-26              0
# 2020-02-27              0
# 2020-02-28              2
# 2020-02-29              0
# ...                   ...
# 2020-05-26          31372
# 2020-05-27          40053
# 2020-05-28          57235
# 2020-05-29          51494
# 2020-05-30          56630
#
# [96 rows x 1 columns]

# %%
agrupadodataestado = df[['date', 'state']].groupby(df['new_confirmed'])

# %%
agrupadodataestado.sum()
# Out:
#                      date state
# new_confirmed
# -1289          2020-05-23    BA
# -1203          2020-05-26    TO
# -1192          2020-04-26    PE
# -1081          2020-05-25    TO
# -1070          2020-05-21    BA
# ...                   ...   ...
#  4467          2020-05-30    RJ
#  5586          2020-05-30    SP
#  5691          2020-05-29    SP
#  6382          2020-05-28    SP
#  9427          2020-05-30    CE
#
# [819 rows x 2 columns]

# %%
df2 = agrupadodata

# %%
df2.head()
# Out:
#             new_confirmed
# date
# 2020-02-25              2
# 2020-02-26              0
# 2020-02-27              0
# 2020-02-28              2
# 2020-02-29              0

# %%
df2.to_excel(r'C:\Users\Costa\Desktop\Udemy Python - Básico ao Avançado\xorajobs\exportei.xlsx', index = True)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6))
plt.plot(df['epidemiological_week'], df['new_confirmed'])
plt.xlabel('Semana Epidemiológica')
plt.ylabel('Casos')
plt.title('Casos X Semana Epidemiológica')
plt.savefig('casos.png')

# %%
plt.figure(figsize=(8, 6))
plt.plot(df['epidemiological_week'], df['new_deaths'])
plt.xlabel('Semana Epidemiológica')
plt.ylabel('Mortes')
plt.title('Mortes X Semana Epidemiológica')
plt.savefig('mortes.png')
